# %% [markdown]
# # Análise Univariada

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %%
# http://notepad.pw/bccbigdata

# !wget 'http://www.ppgia.pucpr.br/~jean.barddal/datascience/ommlbd_familiar.csv'
df = pd.read_csv('ommlbd_familiar.csv')
df.head(5)
# Out:
# --2022-08-16 01:28:00--  http://www.ppgia.pucpr.br/~jean.barddal/datascience/ommlbd_familiar.csv
# Resolving www.ppgia.pucpr.br (www.ppgia.pucpr.br)... 104.18.10.132, 104.18.11.132, 2606:4700::6812:b84, ...
# Connecting to www.ppgia.pucpr.br (www.ppgia.pucpr.br)|104.18.10.132|:80... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: https://www.ppgia.pucpr.br/~jean.barddal/datascience/ommlbd_familiar.csv [following]
# --2022-08-16 01:28:00--  https://www.ppgia.pucpr.br/~jean.barddal/datascience/ommlbd_familiar.csv
# Connecting to www.ppgia.pucpr.br (www.ppgia.pucpr.br)|104.18.10.132|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 38872006 (37M) [text/csv]
# Saving to: ‘ommlbd_familiar.csv’
#
# ommlbd_familiar.csv 100%[===================>]  37.07M  75.2MB/s    in 0.5s
#
# 2022-08-16 01:28:00 (75.2 MB/s) - ‘ommlbd_familiar.csv’ saved [38872006/38872006]
# ...

# %%
# substituir os valores "nulos" por valores faltantes de fato

df.replace(-9999, np.nan, inplace=True)
df.describe().T
# Out:
#                             count           mean            std    min  \
# HS_CPF                   438924.0  324130.294748  205825.214515    0.0
# QTDPESSOASCASA           165520.0       2.993542       1.231989    2.0
# MENORRENDACASA           165520.0    1211.068753    1438.357620  400.0
# MAIORRENDACASA           165520.0    5259.854398    6079.701542  400.0
# SOMARENDACASA            165520.0    8306.661431    8445.786665  800.0
# MEDIARENDACASA           165520.0    2902.041409    2984.834142  400.0
# MAIORIDADECASA           165472.0      50.904298      13.807128    4.0
# MENORIDADECASA           165472.0      24.809690      10.886317    1.0
# MEDIAIDADECASA           165472.0      36.196613      10.893769    4.0
# INDICMENORDEIDADE        165520.0       0.064669       0.245941    0.0
# COBRANCABAIXOCASA        165520.0       0.059981       0.237452    0.0
# COBRANCAMEDIOCASA        165520.0       0.005486       0.073863    0.0
# ...

# %%
sns.distplot(df['MEDIARENDACASA'])
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.distplot(df['MEDIARENDACASA'], kde=False)
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.distplot(df['MEDIARENDACASA'], kde=False, bins=10)
plt.show()

# %%
sns.distplot(df['MEDIARENDACASA'], kde=False)
plt.xlim(0, 10000)
plt.show()

# %%
sns.boxplot(df['MEDIARENDACASA'])
plt.show()
# inicio da caixa 1quartil (25%)
# barra indica o 2quartil  (50%)(mediana)
# fim da caixa indica o 3quartil (75)
# * Indicação de quartis
# * Indicação de instãncias
# * Indicação de outliers (barras "whiskers" definem o range de max/min para comportamento padrão)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
sns.violinplot(df['MEDIARENDACASA'])
plt.plot()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# []

# %%
sns.countplot(df['BOLSAFAMILIACASA'])
plt.plot()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# []

# %% [markdown]
# # Análise Multivariada

# %%
# !wget http://www.ppgia.pucpr.br/~jean.barddal/datascience/Salaries.csv
df = pd.read_csv('Salaries.csv')
df.describe()
# Out:
# URL transformed to HTTPS due to an HSTS policy
# --2022-08-16 01:28:10--  https://www.ppgia.pucpr.br/~jean.barddal/datascience/Salaries.csv
# Resolving www.ppgia.pucpr.br (www.ppgia.pucpr.br)... 104.18.10.132, 104.18.11.132, 2606:4700::6812:b84, ...
# Connecting to www.ppgia.pucpr.br (www.ppgia.pucpr.br)|104.18.10.132|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 14954 (15K) [text/csv]
# Saving to: ‘Salaries.csv’
#
# Salaries.csv        100%[===================>]  14.60K  --.-KB/s    in 0s
#
# 2022-08-16 01:28:11 (77.8 MB/s) - ‘Salaries.csv’ saved [14954/14954]
#        Unnamed: 0  yrs.since.phd  yrs.service         salary
# count  397.000000     397.000000   397.000000     397.000000
# mean   199.000000      22.314861    17.614610  113706.458438
# std    114.748275      12.887003    13.006024   30289.038695
# min      1.000000       1.000000     0.000000   57800.000000
# 25%    100.000000      12.000000     7.000000   91000.000000
# ...

# %%
sns.distplot(df['salary'])
plt.plot()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# []

# %%
df_homems = df[df['sex'] == 'Male']
df_mulheres = df[df['sex'] == 'Female']
sns.distplot(df_homems['salary'], kde=False)
sns.distplot(df_mulheres['salary'], kde=False)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.boxplot(df['salary'], y=df['sex'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
# Criar a base
df = pd.DataFrame({
    'x' : np.random.normal(10, 1.2, 20000),
    'y' : np.random.normal(10, 1.2, 20000),
    'group' : np.repeat('A', 20000)
})

tmp1 = pd.DataFrame({
    'x' : np.random.normal(14.5, 1.2, 20000),
    'y' : np.random.normal(14.5, 1.2, 20000),
    'group' : np.repeat('B', 20000)
})

tmp2 = pd.DataFrame({
    'x' : np.random.normal(9.5, 1.5, 20000),
    'y' : np.random.normal(15.5, 1.5, 20000),
    'group' : np.repeat('C', 20000)
})

# concatenating the data
df = df.append(tmp1).append(tmp2)

df.head(5)
# Out:
#            x          y group
# 0   9.960066  10.401784     A
# 1   9.093206  10.628186     A
# 2  11.340974   9.147747     A
# 3  11.340105  11.825785     A
# 4   9.693127   9.260332     A

# %%
# plotar distribuição
sns.scatterplot(df['x'], df['y'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
sns.scatterplot(df['x'], df['y'], size=.01)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
sns.scatterplot(df['x'], df['y'], size=.01, alpha=.1)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
df = df.reset_index(drop = True)
sns.kdeplot(data=df, x='x', y='y', shade=True)

# %%
sns.jointplot(df['x'], df['y'], alpha=.1)

# %%
sns.scatterplot(df['x'], df['y'], alpha=.01, hue=df['group'])

# %%
# Facet grid
g = sns.FacetGrid(df, col='group', hue='group')
g = g.map(plt.scatter,'x','y')
plt.show()

# %%
dfa=df[df['group']=='A']
dfb=df[df['group']=='B']
dfc=df[df['group']=='C']

sns.scatterplot(dfc['x'],dfc['y'], color='gray', alpha=.01)
sns.scatterplot(dfb['x'],dfb['y'], color='gray', alpha=.01)
sns.scatterplot(dfa['x'],dfa['y'], color='blue', alpha=.01)
plt.show()

# %%
# create a new dataset
a = np.concatenate([
                    np.random.normal(2, 4, 1000),
                    np.random.normal(4, 4, 1000),
                    np.random.normal(1, 2,  500),
                    np.random.normal(10, 2, 500),
                    np.random.normal(8, 4, 1000),
                    np.random.normal(10, 4, 1000)
])

df = pd.DataFrame({
    'x': np.repeat(range(1,6), 1000),
    'y': a
})

# %%
sns.scatterplot(df['x'], df['y'])

# %%
sns.stripplot(df['x'],df['y'], size=2)

# %%
sns.kdeplot(data=df, x='x', y='y', shade=True)

# %%
sns.jointplot(df['x'], df['y'], alpha=.1)

# %%
sns.boxplot(x=df['x'], y=df['y'])

# %%
sns.violinplot(x=df['x'], y=df['y'])

# %%
sns.stripplot(df['x'],df['y'], size=3, alpha=.3, jitter=.3)
sns.boxplot(x=df['x'], y=df['y'])
plt.show()
